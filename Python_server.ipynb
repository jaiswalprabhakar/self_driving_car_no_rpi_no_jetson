# %%
from time import sleep
import urllib.request
url = "http://192.168.43.123"  # ESP's IP, ex: http://192.168.102/ (Check serial console while uploading the ESP code, the IP will be printed)

def get_data():
	global data

	n = urllib.request.urlopen(url).read() # get the raw html data in bytes (sends request and warn our esp8266)
	n = n.decode("utf-8") # convert raw html bytes format to string :3

	data = n
#	data = n.split() #<optional> split datas we got. (if you programmed it to send more than one value) It splits them into seperate list elements.
#	data = list(map(int, data)) #<optional> turn datas to integers, now all list elements are integers.

# Example usage
while True:
	get_data()
	print("Your data(s) which we received from ESP: "+data)
	sleep(1)
# Out:
# Your data(s) which we received from ESP: 66
# Your data(s) which we received from ESP: 67
# Your data(s) which we received from ESP: 68
# Your data(s) which we received from ESP: 69
# Your data(s) which we received from ESP: 70
# Your data(s) which we received from ESP: 71
# Your data(s) which we received from ESP: 72
# Your data(s) which we received from ESP: 73
# Your data(s) which we received from ESP: 74
# Your data(s) which we received from ESP: 75
# Your data(s) which we received from ESP: 76
# Your data(s) which we received from ESP: 77
# Your data(s) which we received from ESP: 78
# Your data(s) which we received from ESP: 79
# Your data(s) which we received from ESP: 80
# Your data(s) which we received from ESP: 81
# Your data(s) which we received from ESP: 82
# Your data(s) which we received from ESP: 83
# Your data(s) which we received from ESP: 84
# Your data(s) which we received from ESP: 85
# Your data(s) which we received from ESP: 86
# Your data(s) which we received from ESP: 87
# Your data(s) which we received from ESP: 88
# Your data(s) which we received from ESP: 89
# Your data(s) which we received from ESP: 90
# Your data(s) which we received from ESP: 91
# Your data(s) which we received from ESP: 92
# Your data(s) which we received from ESP: 93
# Your data(s) which we received from ESP: 94
# Your data(s) which we received from ESP: 95
# Your data(s) which we received from ESP: 96
# Your data(s) which we received from ESP: 97
# Your data(s) which we received from ESP: 98
# Your data(s) which we received from ESP: 99
# Your data(s) which we received from ESP: 100
# Your data(s) which we received from ESP: 101
# Your data(s) which we received from ESP: 102
# Your data(s) which we received from ESP: 103
# Your data(s) which we received from ESP: 104
# Your data(s) which we received from ESP: 105
# Your data(s) which we received from ESP: 106
# Your data(s) which we received from ESP: 107
# Your data(s) which we received from ESP: 108
# Your data(s) which we received from ESP: 109
# Your data(s) which we received from ESP: 110
# Your data(s) which we received from ESP: 111
# Your data(s) which we received from ESP: 112
# Your data(s) which we received from ESP: 113
# Your data(s) which we received from ESP: 114
# Your data(s) which we received from ESP: 115
# Your data(s) which we received from ESP: 116
# Your data(s) which we received from ESP: 117
# Your data(s) which we received from ESP: 118
# Your data(s) which we received from ESP: 119
# Your data(s) which we received from ESP: 120
# Your data(s) which we received from ESP: 121
# Your data(s) which we received from ESP: 122
# Your data(s) which we received from ESP: 123
# Your data(s) which we received from ESP: 124
# Your data(s) which we received from ESP: 125
# Your data(s) which we received from ESP: 126
# Your data(s) which we received from ESP: 127
# Your data(s) which we received from ESP: 128
# Your data(s) which we received from ESP: 129
# Your data(s) which we received from ESP: 130
# Your data(s) which we received from ESP: 131
# Your data(s) which we received from ESP: 132
# Your data(s) which we received from ESP: 133
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\http\client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-6-357e99c13364> in <module>
#      15 # Example usage
#      16 while True:
# ---> 17         get_data()
#      18         print("Your data(s) which we received from ESP: "+data)
#      19         sleep(1)
#
# <ipython-input-6-357e99c13364> in get_data()
#       6         global data
#       7
# ----> 8         n = urllib.request.urlopen(url).read() # get the raw html data in bytes (sends request and warn our esp8266)
#       9         n = n.decode("utf-8") # convert raw html bytes format to string :3
#      10
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\urllib\request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# c:\users\prabhakar jaiswal\appdata\local\programs\python\python36\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [WinError 10053] An established connection was aborted by the software in your host machine>
